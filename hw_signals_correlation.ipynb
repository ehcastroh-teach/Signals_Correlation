# %% [markdown]
# # Signals and Correlation
#
# Apply correlation analysis to real-world environmental data. You will compute correlation coefficients by hand and using Python, compare correlation types, and decide which method fits a given dataset.
#
# ***Summary***
# 1. [The Basics](#the-basics)
# 2. [Theoretical Questions](#theoretical-questions)
# 3. [Comparison of Correlation Type](#correlation-type)

# %% [markdown]
# ***
# <a id='the-basics'></a>
# ## 1. The Basics
#
# Practice computing and interpreting Pearson correlation using environmental health data - a dataset linking air quality measurements to daily death counts.

# %% [markdown]
# The table below records ozone levels, temperature, relative humidity, and number of deaths across 12 observations.
#
# | Ozone (ppm) | Temperature (C) | Relative Humidity | Deaths |
# |---|---|---|---|
# | 4.59 | -0.2 | 0.757 | 199 |
# | 4.88 | 0.1 | 0.775 | 231 |
# | 4.71 | 0.9 | 0.813 | 210 |
# | 4.14 | 0.5 | 0.854 | 203 |
# | 2.01 | 4.3 | 0.935 | 224 |
# | 2.40 | 7.1 | 0.964 | 198 |
# | 4.08 | 5.2 | 0.935 | 180 |
# | 3.13 | 3.5 | 0.815 | 188 |
# | 2.05 | 3.2 | 0.883 | 168 |
# | 5.19 | 5.3 | 0.854 | 194 |
# | 3.59 | 3.0 | 0.926 | 223 |
# | 12.87 | 4.8 | 0.942 | 201 |

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats

col_ozone = np.array([4.59, 4.88, 4.71, 4.14, 2.01, 2.4, 4.08, 3.13, 2.05, 5.19, 3.59, 12.87])
col_temp  = np.array([-0.2, 0.1, 0.9, 0.5, 4.3, 7.1, 5.2, 3.5, 3.2, 5.3, 3.0, 4.8])
col_humid = np.array([.757, .775, .813, .854, .935, .964, .935, .815, .883, .854, .926, .942])
col_death = np.array([199, 231, 210, 203, 224, 198, 180, 188, 168, 194, 223, 201])

# %% [markdown]
# **Q1 a) Compute the mean and standard deviation of "Relative Humidity" and "Deaths", and the covariance between them. Store results in the variables below.**
#
# *Hint:* Use [`np.mean`](https://numpy.org/doc/stable/reference/generated/numpy.mean.html), [`np.std`](https://numpy.org/doc/stable/reference/generated/numpy.std.html), and [`np.cov`](https://numpy.org/doc/stable/reference/generated/numpy.cov.html) (note: `np.cov` returns a 2x2 matrix; the off-diagonal element is the covariance).

# %%
### YOUR CODE HERE ###
q1a_mean_relative_humidity = ...
q1a_mean_number_deaths = ...
q1a_std_relative_humidity = ...
q1a_std_number_deaths = ...
q1a_covariance = ...

q1a_mean_relative_humidity, q1a_mean_number_deaths, q1a_std_relative_humidity, q1a_std_number_deaths, q1a_covariance

# %% [markdown]
# **Q1 b) Calculate the Pearson correlation coefficient between "Relative Humidity" and "Deaths". Show your work in the markdown cell below using LaTeX, then confirm with code. Store the result in `q1b`.**
#
# *Hint:* You have already computed all the components needed. The Pearson formula is: $r = \frac{cov(X,Y)}{\sigma_X \sigma_Y}$

# %% [markdown]
# **Work (LaTeX):**
#
# *Write your step-by-step derivation here using LaTeX math blocks.*

# %%
### YOUR CODE HERE ###
q1b = ...
q1b

# %% [markdown]
# **Q1 c) In general, what does the correlation coefficient tell you about the relationship between "Relative Humidity" and "Deaths"? Answer below.**

# %% [markdown]
# *ANSWER HERE*

# %% [markdown]
# **Q1 d) Which two columns appear to have the strongest linear relationship? Store their names as an array of strings in `q1d`.**
#
# *Hint:* Build a Pandas DataFrame from the four arrays and use `.corr()`.

# %%
### YOUR CODE HERE ###
q1d = ...
q1d

# %% [markdown]
# Now consider the matrix below:
#
# | | A | B | C | D | E |
# |---|---|---|---|---|---|
# | row_1 | 0.1 | 0.32 | 0.2 | 0.4 | 0.8 |
# | row_2 | 0.23 | 0.18 | 0.56 | 0.61 | 0.12 |
# | row_3 | 0.9 | 0.3 | 0.6 | 0.5 | 0.3 |
# | row_4 | 0.34 | 0.75 | 0.91 | 0.19 | 0.21 |

# %%
matrix = np.array([
    [0.1, .32, .2,  0.4, 0.8],
    [.23, .18, .56, .61, .12],
    [.9,  .3,  .6,  .5,  .3 ],
    [.34, .75, .91, .19, .21]
])

# %% [markdown]
# **Q2 a) Compute the correlation matrix between the rows. Store in `q2a`.**
#
# *Hint:* `np.corrcoef(matrix)` treats rows as variables.

# %%
### YOUR CODE HERE ###
q2a = ...
q2a

# %% [markdown]
# **Q2 b) Compute the correlation matrix between the columns. Store in `q2b`.**
#
# *Hint:* `np.transpose(matrix)` may come in handy.

# %%
### YOUR CODE HERE ###
q2b = ...
q2b

# %% [markdown]
# **Q2 c) Which pairs of columns and pairs of rows appear to have a very weak relationship? List the pairs by name in the answer cell below.**
#
# *Hint:* Look for off-diagonal values with absolute value closest to 0 in each correlation matrix.

# %% [markdown]
# *ANSWER HERE*

# %% [markdown]
# ***
# <a id='theoretical-questions'></a>
# ## 2. Theoretical Questions
#
# For Questions 3a through 3d, answer `True` or `False` as a Python boolean.

# %% [markdown]
# **Q3 a) The relationship between correlation and covariance can be written as:**
#
# $$\rho_{X,Y} = corr(X,Y) = \frac{cov(X,Y)}{\sigma_X \sigma_Y} = \frac{E[(X - \mu_X)(Y - \mu_Y)]}{\sigma_X \sigma_Y}$$

# %%
### YOUR CODE HERE ###
q3a = ...
q3a

# %% [markdown]
# **Q3 b) Property: $-1 \leq cor(X, Y) \leq 1$, where $X$ and $Y$ are rows or columns of numbers.**

# %%
### YOUR CODE HERE ###
q3b = ...
q3b

# %% [markdown]
# **Q3 c) Property: $cor(X, Y) = 1 \iff Y$ is any function of $X$ with a positive slope.**

# %%
### YOUR CODE HERE ###
q3c = ...
q3c

# %% [markdown]
# **Q3 d) Property: $cor(X, Y) = -1 \iff Y$ is a linear function of $X$ with a positive slope.**

# %%
### YOUR CODE HERE ###
q3d = ...
q3d

# %% [markdown]
# **Q3 e) Show that $-1 \leq cor(X, Y) \leq 1$ implies $-\sigma_X \sigma_Y \leq cov(X, Y) \leq \sigma_X \sigma_Y$. Use LaTeX in the answer cell below.**
#
# *Hint:* Multiply both sides of the correlation inequality by $\sigma_X \sigma_Y$. Both standard deviations are non-negative, so the inequality direction does not flip.

# %% [markdown]
# **Answer (LaTeX):**
#
# *Write your derivation here.*

# %% [markdown]
# **Q3 f) For each description below, type the name of the correlation method as a string. Store results in `q3f_1`, `q3f_2`, `q3f_3`.**
#
# 1. Uses the standard Pearson correlation coefficient.
# 2. Uses a coefficient that explicitly counts concordant and discordant pairs.
# 3. Uses a coefficient based on the covariance of the rank variables (ordinal variables).

# %%
### YOUR CODE HERE ###
q3f_1 = ...
q3f_2 = ...
q3f_3 = ...

q3f_1, q3f_2, q3f_3

# %% [markdown]
# ***
# <a id='correlation-type'></a>
# ## 3. Comparison of Correlation Type
#
# Apply and compare Pearson, Spearman, and Kendall-tau on a dataset with real-world structure: the UCI Wine Recognition dataset, which contains chemical measurements of wines from three Italian cultivars. The goal here is to understand how each method responds differently to the data's characteristics.

# %%
from sklearn.datasets import load_wine

wine = load_wine(as_frame=True)
df_wine = wine.frame
df_wine.head()

# %% [markdown]
# **Q4 a) Compute the Pearson correlation between 'alcohol' and 'color_intensity'. Store in `q4a`.**
#
# *Hint:* Use [`DataFrame.corr`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.corr.html) or the column-level `.corr()` method with `method='pearson'`.

# %%
### YOUR CODE HERE ###
q4a = ...
q4a

# %% [markdown]
# **Q4 b) Compute the Spearman correlation between 'alcohol' and 'color_intensity'. Store in `q4b`. Then compare the two values - are they similar or different? What does a large difference suggest?**
#
# *Hint:* Pass `method='spearman'` to `.corr()`.

# %%
### YOUR CODE HERE ###
q4b = ...
q4b

# %% [markdown]
# *ANSWER HERE*

# %% [markdown]
# **Q4 c) Compute the Kendall-tau correlation and p-value between 'alcohol' and 'color_intensity'. Store the coefficient in `q4c_tau` and the p-value in `q4c_pval`.**
#
# *Hint:* Use [`scipy.stats.kendalltau`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.kendalltau.html).

# %%
# TODO: verify against current scipy docs
### YOUR CODE HERE ###
q4c_tau  = ...
q4c_pval = ...

print(f"Kendall tau: {q4c_tau:.4f}, p-value: {q4c_pval:.4f}")

# %% [markdown]
# **Q4 d) The 'ash' column contains a few high outliers (values > 3.2). Compute the Pearson and Spearman correlations between 'ash' and 'malic_acid', both on the full dataset and with those outliers removed. Store all four values below. Then explain which method is more robust and why.**
#
# *Hint:* Use boolean indexing to filter out rows where `df_wine['ash'] > 3.2`.

# %%
### YOUR CODE HERE ###
q4d_pearson_full    = ...
q4d_spearman_full   = ...

df_trimmed = df_wine[df_wine['ash'] <= 3.2]

q4d_pearson_trimmed  = ...
q4d_spearman_trimmed = ...

print(f"Pearson  (full):    {q4d_pearson_full:.4f}")
print(f"Pearson  (trimmed): {q4d_pearson_trimmed:.4f}")
print(f"Spearman (full):    {q4d_spearman_full:.4f}")
print(f"Spearman (trimmed): {q4d_spearman_trimmed:.4f}")

# %% [markdown]
# *ANSWER HERE*

# %% [markdown]
# **Q4 e) [OPTIONAL] Choose three feature pairs from `df_wine`. For each pair, compute all three correlation types and arrange the results in a Pandas DataFrame with feature pairs as rows and method names ('pearson', 'spearman', 'kendall') as columns. Store in `q4e`.**

# %%
### YOUR CODE HERE ###
q4e = ...
q4e
